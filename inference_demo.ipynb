# %%
import utils
import inference

# %%
inference.disable_gpu_preallocation()
model = inference.load_model("thunder")

# %%
video_path = "data/KeithNotationPhrase.mmdet_just_body.retracked.proofread.track0.mp4"
fidx = 100

img = utils.read_frame(video_path, fidx)
points, scores = inference.predict(model, img)

utils.plot_img(img)
utils.plot_pose(points);
